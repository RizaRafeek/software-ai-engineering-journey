# %%
def is_palindrome():
    text = input("Enter your text:")
    text = text.lower().replace(" ", "")
    reverse_text = text[::-1]
    if text == reverse_text:
        print("The text is a palindrome")
    else:
        print("The text is not a palindrome")

# %%
def is_prime(num):
    if num <= 1:
        return False
    if num == 2:
        return True
    if n%2 == 0:
        return False

# %%
def count_word(text):
    words = text.split()
    word_count = {}
    for word in words:
        if word in wrd_count:
            word_count[word] +=1
        else:
            word_count[word] = 1

# %%
def calculate_transaction(transaction_list):
    sum = 0
    subtract = 0
    for item in transaction_list:
        if item["type"] == "deposit":
            sum += item["amount"]
        elif item["type"] == "withdrawal":
            subtract += item["amount"]

    final_amount = sum - subtract
    return final_amount

# %%
def calculate_grade(scores):
    avg = sum(scores) / len(scores)
    for score in scores:
        if score >= avg + 10:
            return "A"
        elif score <= avg - 10:
            return "F"
        else:
            return "B"

# %%
class Student:
    def __init__(self, name, mark1, mark2, mark3):
        self.name = name
        self.mark1 = mark1
        self.mark2 = mark2
        self.mark3 = mark3
    def calculate_average(self):
        return (self.mark1 + self.mark2 + self.mark3) / 3

# %%
s1 = Student('hala', 70, 80, 45)
average = s1.calculate_average()
print(average)
# Out:
# 65.0

# %%
class Car:
    def __init__(self):
        self.acc = False
        self.brk = False
        self.clutch = False

    def  start(self):
        self.clutch = True
        self.acc = True
        print("Car started..")

car1 = Car()
car1.start()                   #Abstraction : only what the user need to see is shown : other unecessary internal mechannism is hidden to the user
# Out:
# Car started..

# %%
class Account:
    def __init__(self, balance, account_no):
        self.balance = balance
        self.account_no = account_no

    def debit(self, amount):
        self.balance -= amount
        print("Rs.",amount ,"was debited")

    def credit(self, amount):
        self.balance += amount
        print("Rs.", amount, "was credited")

    def print_balance(self):
        print(f"Your balance is {self.balance}")

# %%
acc1 = Account(3000, 404940)
print(acc1.print_balance())
# Out:
# Your balance is 3000
# None
